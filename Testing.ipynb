# %%
import qiskit
import pylatexenc

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.24.0', 'qiskit-aer': '0.12.0', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.20.2', 'qiskit': '0.43.0', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('c7ab41fa91959c5b7ae61c86cb5e59a8e25512875fefda0df862450d438b5d706e8a58288e372884c6e54899c6038ba6d098fb269ac08bf5d7a004b306dbe182')
# Out:
# /var/folders/z2/14rgf6cd42159h5c22zxvs1h0000gn/T/ipykernel_36611/2908992811.py:1: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   IBMQ.save_account('c7ab41fa91959c5b7ae61c86cb5e59a8e25512875fefda0df862450d438b5d706e8a58288e372884c6e54899c6038ba6d098fb269ac08bf5d7a004b306dbe182')
# configrc.store_credentials:WARNING:2023-05-10 00:31:27,020: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit import *
# %matplotlib inline

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)

circuit = QuantumCircuit(qr, cr)

# %%
circuit.draw()
# Out:
#
# q3_0:
#
# q3_1:
#
# c3: 2/

# %%
# Applying hadamard gate

circuit.h(qr[0])
circuit.draw(output='mpl')

# %%
# Controlled X

circuit.cx(qr[0], qr[1])
circuit.draw(output='mpl')

# %%
# measuring

circuit.measure(qr, cr)
circuit.draw(output='mpl')

# %%
# Simulator

simulator = Aer.get_backend('qasm_simulator')

# %%
result = execute(circuit, backend=simulator).result()

# %%
from qiskit.tools.visualization import plot_histogram

plot_histogram(result.get_counts(circuit))

# %%
import pylatexenc
from qiskit import *
# %matplotlib inline
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

n = 2

qc = QuantumCircuit(n)
plot_state_qsphere(qc)

# %%
import pylatexenc
from qiskit import *
# %matplotlib inline
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere
from qiskit.tools.visualization import plot_histogram
import numpy as np

n = 1

qc = QuantumCircuit(n)


qc.ry(np.pi/6, 0)
qc.ry(np.pi/3, 1)


# Simulator
# simulator = Aer.get_backend('qasm_simulator')
# result = execute(qc, backend=simulator).result()
# plot_histogram(result.get_counts(qc))

# %%
from qiskit import *
# %matplotlib inline
from qiskit.tools.visualization import plot_histogram


qr = QuantumRegister(2)
cr = ClassicalRegister(2)

circuit = QuantumCircuit(qr, cr)

circuit.ry(np.pi/3, qr[0])
# circuit.ry(np.pi/2, qr[1])

circuit.measure(qr, cr)

circuit.draw(output='mpl')

# %%
# Simulator
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()
plot_histogram(result.get_counts(circuit))
